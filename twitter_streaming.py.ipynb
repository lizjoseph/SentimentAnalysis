# %%
#Import the necessary methods from tweepy library
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream

#Variables that contains the user credentials to access Twitter API 
access_token = "712273970519736321-Szvjuzykjo0SDertGY7VFUy82zF8Ci6"
access_token_secret = "SwYUOTF1D2faJeJlPbefl8ZrGxRRThVx1TCn3UHLbJZmK"
consumer_key = "nrTKdXee52XEkDjsJLt5fPi3P"
consumer_secret = "3SsaxohrkakdcV52iJidVTxZHQvF4Z0bRxKQJfYkth3OnUEqe7"


#This is a basic listener that just prints received tweets to stdout.
class StdOutListener(StreamListener):

    def on_data(self, data):
        print data
        return True

    def on_error(self, status):
        print status


if __name__ == '__main__':

    #This handles Twitter authetification and the connection to Twitter Streaming API
    l = StdOutListener()
    auth = OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    stream = Stream(auth, l)

    #This line filter Twitter Streams to capture data by the keywords: 'python', 'javascript', 'ruby'
    stream.filter(track = ['#ANC', '#EFF','#DA', '#IFP','VFPlus','African National Congress','Democratic Allience','Economic Freedom Fighters','Vryheidsfront Plus','Inkatha Freedom Party','Pieter Mulder','Mmusi','Mmusi Maimane','Jacob Zuma','Zuma','Zupta','Hellen Zilla', 'Zilla', 'Malema','Julius Malema', ], locations = [-16.4684,-46.9900,37.9932,-22.1247],languages = ['en'])
# Out:
# {"created_at":"Wed Aug 24 19:04:15 +0000 2016","id":768524338177933312,"id_str":"768524338177933312","text":"Only you can help your yourself. Believe in you and be the best version of yourself possible \ud83d\ude46","source":"\u003ca href=\"http:\/\/twitter.com\/download\/android\" rel=\"nofollow\"\u003eTwitter for Android\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":1418632466,"id_str":"1418632466","name":"Murunwa Neo","screen_name":"mohneo1","location":"Jozi city light","url":null,"description":"Violin,journalism, law,poetry, writing and blogging\r\nVenturing into making TV\r\nInspired by @mapsmaponyane\r\nFoodie. Aspiring philanthropist & polymath","protected":false,"verified":false,"followers_count":107,"friends_count":146,"listed_count":0,"favourites_count":11,"statuses_count":515,"created_at":"Fri May 10 17:17:41 +0000 2013","u
# ...

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.axes
import re

tweets_data_path = '///home/commader/datasciences/liz/twitter_data.txt'

tweets_data = []
tweets_file = open(tweets_data_path, "r")

for line in tweets_file:
    try:
        tweet = json.loads(line)
        tweets_data.append(tweet)
    except:
        continue
        
    tweets = pd.DataFrame()
    
    tweets_by_lang = tweets['lang'].value_counts()
    

    fig, ax = plt.subplots()
    ax.tick_params(axis='x', labelsize=15)
    ax.tick_params(axis='y', labelsize=10)
    ax.set_xlabel('Languages', fontsize=15)
    ax.set_ylabel('Number of tweets' , fontsize=15)
    ax.set_title('Top 5 languages', fontsize=15, fontweight='bold')
    tweets_by_lang[:5].plot(ax=ax, kind='bar', color='red')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-f596e2ebe234> in <module>()
#      19     tweets = pd.DataFrame()
#      20
# ---> 21     tweets_by_lang = tweets['lang'].value_counts()
#      22
#      23     fig, ax = plt.subplots()
#
# /home/commader/miniconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /home/commader/miniconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# ...

# %%
def word_in_text(word, text):
    word = word.lower()
    text = text.lower()
    match = re.search(word, text)
    if match:
        return True
    return False

tweets['#ANC'] = tweets['text'].apply(lambda tweet: word_in_text('#ANC', tweet))
tweets['#EFF'] = tweets['text'].apply(lambda tweet: word_in_text('#EFF', tweet))
tweets['#DA'] = tweets['text'].apply(lambda tweet: word_in_text('#DA', tweet))
    
print tweets['#ANC'].value_counts()[True]
print tweets['#EFF'].value_counts()[True]
print tweets['#DA'].value_counts()[True]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-c607a13d857c> in <module>()
#       7     return False
#       8
# ----> 9 tweets['#ANC'] = tweets['text'].apply(lambda tweet: word_in_text('#ANC', tweet))
#      10 tweets['#EFF'] = tweets['text'].apply(lambda tweet: word_in_text('#EFF', tweet))
#      11 tweets['#DA'] = tweets['text'].apply(lambda tweet: word_in_text('#DA', tweet))
#
# /home/commader/miniconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /home/commader/miniconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# ...

# %%
print len(tweets_data)
# Out:
# 21738
